# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
genres_v2 = pd.read_csv('genres_v2.csv')
genres_v2.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_22140\1938947344.py:1: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   genres_v2 = pd.read_csv('genres_v2.csv')
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence  ...                      id  \
# 0          0.013400    0.0556   0.3890  ...  2Vc6NJ9PW9gD9q343XFRKx
# 1          0.000000    0.1180   0.1240  ...  7pgJBLVz5VmnL7uGHmRj6p
# 2          0.000004    0.3720   0.0391  ...  0vSWgAlfpye0WCGeNmuNhy
# ...

# %%
plt.scatter(genres_v2['valence'], genres_v2['mode'])

# %%
plt.scatter(genres_v2['valence'], genres_v2['danceability'])

# %%
plt.scatter(genres_v2['energy'], genres_v2['danceability'])

# %%
plt.scatter(genres_v2['instrumentalness'], genres_v2['speechiness'])

# %%
plt.scatter(genres_v2['energy'], genres_v2['loudness'])
